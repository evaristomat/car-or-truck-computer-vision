# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/custom-convnets).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In these exercises, you'll build a custom convnet with performance competitive to the VGG16 model from Lesson 1.
#
# Get started by running the code cell below.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex5 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# # Design a Convnet #
#
# Let's design a convolutional network with a block architecture like we saw in the tutorial. The model from the example had three blocks, each with a single convolutional layer. Its performance on the "Car or Truck" problem was okay, but far from what the pretrained VGG16 could achieve. It might be that our simple network lacks the ability to extract sufficiently complex features. We could try improving the model either by adding more blocks or by adding convolutions to the blocks we have.
#
# Let's go with the second approach. We'll keep the three block structure, but increase the number of `Conv2D` layer in the second block to two, and in the third block to three.
#
# <figure>
# <!-- <img src="./images/2-convmodel-2.png" width="250" alt="Diagram of a convolutional model."> -->
# <img src="https://i.imgur.com/Vko6nCK.png" width="250" alt="Diagram of a convolutional model.">
# </figure>
#
# # 1) Define Model #
#
# Given the diagram above, complete the model by defining the layers of the third block.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape=[128, 128, 3]),
    layers.MaxPool2D(),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Head
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# # 2) Compile #
#
# To prepare for training, compile the model with an appropriate loss and accuracy metric for the "Car or Truck" dataset.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
q_2.assert_check_passed()
# Out:
# Correct

# %% [markdown]
# Finally, let's test the performance of this new model. First run this cell to fit the model to the training set.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 31s 277ms/step - loss: 0.6825 - binary_accuracy: 0.5734 - val_loss: 0.6705 - val_binary_accuracy: 0.5785
# Epoch 2/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.6684 - binary_accuracy: 0.5949 - val_loss: 0.6599 - val_binary_accuracy: 0.6181
# Epoch 3/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6648 - binary_accuracy: 0.6023 - val_loss: 0.6534 - val_binary_accuracy: 0.6268
# Epoch 4/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.6556 - binary_accuracy: 0.5970 - val_loss: 0.6470 - val_binary_accuracy: 0.6118
# Epoch 5/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6543 - binary_accuracy: 0.6017 - val_loss: 0.6397 - val_binary_accuracy: 0.6211
# Epoch 6/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.6470 - binary_accuracy: 0.6080 - val_loss: 0.6344 - val_binary_accuracy: 0.6409
# Epoch 7/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6460 - binary_accuracy: 0.6156 - val_loss: 0.6285 - val_binary_accuracy: 0.6502
# Epoch 8/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6348 - binary_accuracy: 0.6246 - val_loss: 0.6198 - val_binary_accuracy: 0.6535
# Epoch 9/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.6253 - binary_accuracy: 0.6363 - val_loss: 0.6178 - val_binary_accuracy: 0.6571
# Epoch 10/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.6175 - binary_accuracy: 0.6508 - val_loss: 0.6035 - val_binary_accuracy: 0.6704
# Epoch 11/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.6068 - binary_accuracy: 0.6559 - val_loss: 0.5885 - val_binary_accuracy: 0.6826
# Epoch 12/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.5920 - binary_accuracy: 0.6703 - val_loss: 0.5944 - val_binary_accuracy: 0.6656
# Epoch 13/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.5842 - binary_accuracy: 0.6773 - val_loss: 0.5746 - val_binary_accuracy: 0.6929
# Epoch 14/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.5630 - binary_accuracy: 0.7037 - val_loss: 0.5410 - val_binary_accuracy: 0.7355
# Epoch 15/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.5361 - binary_accuracy: 0.7172 - val_loss: 0.5133 - val_binary_accuracy: 0.7610
# Epoch 16/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.5132 - binary_accuracy: 0.7360 - val_loss: 0.4973 - val_binary_accuracy: 0.7610
# Epoch 17/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.4913 - binary_accuracy: 0.7405 - val_loss: 0.4748 - val_binary_accuracy: 0.7812
# Epoch 18/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.4594 - binary_accuracy: 0.7618 - val_loss: 0.4594 - val_binary_accuracy: 0.7903
# Epoch 19/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.4460 - binary_accuracy: 0.7690 - val_loss: 0.4350 - val_binary_accuracy: 0.8050
# Epoch 20/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.4307 - binary_accuracy: 0.7848 - val_loss: 0.4340 - val_binary_accuracy: 0.8032
# Epoch 21/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.4139 - binary_accuracy: 0.8014 - val_loss: 0.4533 - val_binary_accuracy: 0.7919
# Epoch 22/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.3873 - binary_accuracy: 0.8226 - val_loss: 0.4407 - val_binary_accuracy: 0.8018
# Epoch 23/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.3847 - binary_accuracy: 0.8259 - val_loss: 0.4355 - val_binary_accuracy: 0.8089
# Epoch 24/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.3356 - binary_accuracy: 0.8448 - val_loss: 0.4090 - val_binary_accuracy: 0.8192
# Epoch 25/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.3133 - binary_accuracy: 0.8560 - val_loss: 0.4136 - val_binary_accuracy: 0.8115
# Epoch 26/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2948 - binary_accuracy: 0.8732 - val_loss: 0.4477 - val_binary_accuracy: 0.8056
# Epoch 27/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2924 - binary_accuracy: 0.8743 - val_loss: 0.4749 - val_binary_accuracy: 0.7919
# Epoch 28/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2803 - binary_accuracy: 0.8781 - val_loss: 0.6069 - val_binary_accuracy: 0.7723
# Epoch 29/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2663 - binary_accuracy: 0.8835 - val_loss: 0.4256 - val_binary_accuracy: 0.8295
# Epoch 30/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2869 - binary_accuracy: 0.8747 - val_loss: 0.3988 - val_binary_accuracy: 0.8299
# Epoch 31/50
# 80/80 [==============================] - 5s 57ms/step - loss: 0.2501 - binary_accuracy: 0.8960 - val_loss: 0.3866 - val_binary_accuracy: 0.8448
# Epoch 32/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2358 - binary_accuracy: 0.9062 - val_loss: 0.4632 - val_binary_accuracy: 0.8242
# Epoch 33/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2140 - binary_accuracy: 0.9068 - val_loss: 0.4511 - val_binary_accuracy: 0.8256
# Epoch 34/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2188 - binary_accuracy: 0.9109 - val_loss: 0.6370 - val_binary_accuracy: 0.7826
# Epoch 35/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.2165 - binary_accuracy: 0.9050 - val_loss: 0.6996 - val_binary_accuracy: 0.7806
# Epoch 36/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1977 - binary_accuracy: 0.9183 - val_loss: 0.6742 - val_binary_accuracy: 0.7610
# Epoch 37/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.1911 - binary_accuracy: 0.9179 - val_loss: 0.4877 - val_binary_accuracy: 0.8303
# Epoch 38/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1900 - binary_accuracy: 0.9279 - val_loss: 0.4473 - val_binary_accuracy: 0.8434
# Epoch 39/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1722 - binary_accuracy: 0.9306 - val_loss: 0.4588 - val_binary_accuracy: 0.8493
# Epoch 40/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1738 - binary_accuracy: 0.9334 - val_loss: 0.4730 - val_binary_accuracy: 0.8533
# Epoch 41/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1444 - binary_accuracy: 0.9445 - val_loss: 0.4973 - val_binary_accuracy: 0.8347
# Epoch 42/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1361 - binary_accuracy: 0.9496 - val_loss: 0.5381 - val_binary_accuracy: 0.8319
# Epoch 43/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1348 - binary_accuracy: 0.9525 - val_loss: 0.6612 - val_binary_accuracy: 0.8006
# Epoch 44/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1304 - binary_accuracy: 0.9537 - val_loss: 0.7718 - val_binary_accuracy: 0.7985
# Epoch 45/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1283 - binary_accuracy: 0.9531 - val_loss: 0.7050 - val_binary_accuracy: 0.8204
# Epoch 46/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1120 - binary_accuracy: 0.9650 - val_loss: 0.5951 - val_binary_accuracy: 0.8438
# Epoch 47/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.1143 - binary_accuracy: 0.9609 - val_loss: 0.5822 - val_binary_accuracy: 0.8515
# Epoch 48/50
# 80/80 [==============================] - 4s 56ms/step - loss: 0.1010 - binary_accuracy: 0.9689 - val_loss: 0.5953 - val_binary_accuracy: 0.8485
# Epoch 49/50
# 80/80 [==============================] - 4s 54ms/step - loss: 0.0882 - binary_accuracy: 0.9740 - val_loss: 0.6358 - val_binary_accuracy: 0.8472
# Epoch 50/50
# 80/80 [==============================] - 4s 55ms/step - loss: 0.0817 - binary_accuracy: 0.9777 - val_loss: 0.6464 - val_binary_accuracy: 0.8541

# %% [markdown]
# And now run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 3) Train the Model #
#
# How would you interpret these training curves? Did this model improve upon the model from the tutorial?

# %%
# View the solution (Run this code cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
#
# The learning curves for the model from the tutorial diverged fairly rapidly. This would indicate that it was prone to overfitting and in need of some regularization. The additional layer in our new model would make it even more prone to overfitting. However, adding some regularization with the `Dropout` layer helped prevent this. These changes improved the validation accuracy of the model by several points.

# %% [markdown]
# # Conclusion #
#
# These exercises showed you how to design a custom convolutional network to solve a specific classification problem. Though most models these days will be built on top of a pretrained base, it certain circumstances a smaller custom convnet might still be preferable -- such as with a smaller or unusual dataset or when computing resources are very limited. As you saw here, for certain problems they can perform just as well as a pretrained model.
#
# # Keep Going #
#
# Continue on to [**Lesson 6**](https://www.kaggle.com/ryanholbrook/data-augmentation), where you'll learn a widely-used technique that can give a boost to your training data: **data augmentation**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
